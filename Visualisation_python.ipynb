# %%
## import packages
import pandas as pd
import matplotlib.pyplot as plt # matplotlib package
import seaborn as sns           # seaborn package
import numpy as np

# %%
# read the csv file
df = pd.read_csv('practice.csv') # download from case_study folder (2)
df.shape
# Out:
# (30, 11)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 0          60       RL     8450      Reg    Inside       Gtl            7
# 1          20       RL     9600      Reg       FR2       Gtl            6
# 2          60       RL    11250      IR1    Inside       Gtl            7
# 3          70       RL     9550      IR1    Corner       Gtl            7
# 4          60       RL    14260      IR1       FR2       Gtl            8
#
#    YearBuilt  MasVnrArea ExterQual BsmtExposure
# 0       2003         196        Gd           No
# 1       1976           0        TA           Gd
# 2       2001         162        Gd           Mn
# 3       1915           0        TA           No
# 4       2000         350        Gd           Av

# %%
##
plt.plot(df['MSSubClass'])

# %%
plt.plot(df['MSSubClass'], df['LotArea'],)

# %%
plt.plot(df['MSSubClass'], df['LotArea'], 'bo')

# %%
##
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotArea', 'LotShape', 'LotConfig',
#        'LandSlope', 'OverallQual', 'YearBuilt', 'MasVnrArea', 'ExterQual',
#        'BsmtExposure'],
#       dtype='object')

# %%
plt.scatter(df['MSSubClass'], df['MasVnrArea'])
plt.title('Scatter plot')
plt.xlabel('MSSubClass')
plt.ylabel('MasVnrArea')
# plt.yscale('log')
# Out:
# Text(0, 0.5, 'MasVnrArea')

# %%
plt.scatter(df['MSSubClass'], df['OverallQual'])

# %%
plt.bar(df['MSZoning'], df['LotShape'], width=0.5)
# Out:
# <BarContainer object of 30 artists>

# %%
plt.barh(df['MSZoning'], df['LotShape'])
# Out:
# <BarContainer object of 30 artists>

# %%
###
plt.boxplot(df['MasVnrArea'])
plt.title('Boxplot plot')
plt.xlabel('MasVnrArea')
plt.show()

# %%
sns.boxplot('MasVnrArea' , data = df)

# %%
plt.hist(df['YearBuilt'], bins= 9)
# Out:
# (array([ 1.,  4.,  1.,  1.,  5.,  6.,  0.,  1., 11.]),
#  array([1915.        , 1925.22222222, 1935.44444444, 1945.66666667,
#         1955.88888889, 1966.11111111, 1976.33333333, 1986.55555556,
#         1996.77777778, 2007.        ]),
#  <a list of 9 Patch objects>)

# %%
df.corr()
# Out:
#              MSSubClass   LotArea  OverallQual  YearBuilt  MasVnrArea
# MSSubClass     1.000000 -0.296554    -0.102902  -0.195574   -0.147255
# LotArea       -0.296554  1.000000     0.203113   0.543698    0.448829
# OverallQual   -0.102902  0.203113     1.000000   0.454191    0.722169
# YearBuilt     -0.195574  0.543698     0.454191   1.000000    0.656762
# MasVnrArea    -0.147255  0.448829     0.722169   0.656762    1.000000

# %%
sns.heatmap(df.corr())

# %%
sns.countplot(df['LotShape'])

# %%
sns.boxplot('LotArea' , data = df)

# %%
sns.swarmplot('LotArea' , data = df)

# %%
sns.pairplot(df)

# %%
sns.distplot(df['LotArea'])

# %%
## why distribution plot is important??
### why bell-shape?
